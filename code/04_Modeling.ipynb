# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
import sklearn.metrics

from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.linear_model import Ridge, Lasso, LinearRegression, ElasticNet

from sklearn.pipeline import Pipeline

# %%
class lr_model:
    'Modeling Class, default to LinearRegression'
    def __init__(self, df, target, pipe_steps):
        self.df = df
        self.target = self.df[target]
        self.features = self.df.drop(target, axis=1)
        
        self.num_features = self.features.select_dtypes(include='number')
        self.nom_features = self.features.select_dtypes(exclude='number')
        
        self.pipe = Pipeline(pipe_steps)
        
        self.summary = pd.DataFrame({'random_state' : [], 'val_score': [], 'train_score' : [], 'test_score' : []})
        
    def test_models(self, run_time=3):
        'Run Models X amount of time with different random state'
        for i in np.random.choice(100, run_time, replace=False):
            seed = i
            X = self.features
            y = self.target

            X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=seed) 
            self.pipe.fit(X_train, y_train)

            val_score = round(cross_val_score(self.pipe, X_train, y_train, cv=5).mean(), 2)
            test_score = round(self.pipe.score(X_test, y_test), 2)
            train_score = round(self.pipe.score(X_train, y_train), 2)

            self.summary = self.summary.append({'random_state' : i, 'val_score': val_score, 
                                 'train_score' : train_score, 'test_score' : test_score}, ignore_index=True)
        
        return self.summary
    
    def final_model(self, seed):
        X = self.features
        y = self.target

        X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=seed) 
        self.pipe.fit(X_train, y_train)
    
    def predictions(self, data):
        return self.pipe.predict(data)
                
        
    def coef_score(self):
        
        X = self.features
        y = self.target
        X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=8) 
        self.model.fit(X_train, y_train)
        
                    
        val_score = cross_val_score(self.model, X_train, y_train, cv=5).mean()
        test_score = self.model.score(X_test, y_test)
        train_score = self.model.score(X_train, y_train)
        
        
        summary = pd.DataFrame({"coefficients": np.transpose([(round(coef, 2)) for coef in self.model.coef_]), 
                             'avg_feature_value' : self.features.mean(), 
                             'avg_feature__median' : self.features.median()})
        
        summary['avg_change'] = summary['avg_feature_value'] * summary['coefficients']
        summary['count'] = self.features[self.features > 0].count()
        
        return summary.sort_values('avg_change', ascending=False)

# %%
df = pd.read_csv('../datasets/model_data.csv')

# %%
lr_mysteps = [
    ('sc', StandardScaler()),
    ('lr', LinearRegression()) # estimator         
    ]

# %%
lr_model = lr_model(df, 'saleprice', lr_mysteps)

# %%
lr_model.test_models(10)
# Out:
#    random_state     val_score  train_score    test_score
# 0          18.0  7.800000e-01         0.93  9.200000e-01
# 1           8.0  7.700000e-01         0.93  8.800000e-01
# 2           3.0 -1.394507e+22         0.93  8.800000e-01
# 3          13.0 -1.935087e+24         0.93  8.700000e-01
# 4           6.0 -1.120808e+25         0.93  8.900000e-01
# 5          33.0  8.500000e-01         0.94  8.600000e-01
# 6          19.0 -1.631236e+21         0.93  8.500000e-01
# 7          96.0  8.800000e-01         0.93  8.900000e-01
# 8          57.0 -2.681459e+18         0.93 -3.676100e+24
# 9          85.0  8.000000e-01         0.93  8.700000e-01

# %%
ridge_mysteps = [
    ('sc', StandardScaler()),
    ('lr', Ridge()) # estimator         
    ]

# %%
ridge_model = lr_model(df, 'saleprice', ridge_mysteps)

# %%
ridge_model.test_models(10)
# Out:
#    random_state  val_score  train_score  test_score
# 0          57.0       0.88         0.93        0.91
# 1          30.0       0.92         0.94        0.22
# 2          60.0       0.67         0.93        0.91
# 3          15.0       0.76         0.93        0.89
# 4          29.0       0.88         0.93        0.91
# 5          43.0       0.77         0.94        0.87
# 6          81.0       0.89         0.93        0.89
# 7          48.0       0.79         0.93        0.90
# 8          21.0       0.83         0.93        0.89
# 9          62.0       0.90         0.93        0.31

# %%
lasso_mysteps = [
    ('sc', StandardScaler()),
    ('lr', Lasso()) # estimator         
    ]

# %%
lasso_model = lr_model(df, 'saleprice', lasso_mysteps)

# %%
lasso_model.test_models(10)
# Out:
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 319015301562.8583, tolerance: 944247000.6463385
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 243646842143.8922, tolerance: 782708020.0451404
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 257970703577.80832, tolerance: 781279405.5981704
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 251799906367.9715, tolerance: 782443285.6422516
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 226364891080.1569, tolerance: 693003642.8545661
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 243018560868.61914, tolerance: 736753776.7324629
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 323168337049.8858, tolerance: 950438558.8821981
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 255022450908.2172, tolerance: 779039844.1607049
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 255453870542.19116, tolerance: 742201317.605237
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 217861874423.5209, tolerance: 744015412.5306264
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 250464216381.13403, tolerance: 759464237.9898754
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 251528533919.32367, tolerance: 776834461.2588376
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 324729050746.3846, tolerance: 997464319.6750358
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 235421020287.9778, tolerance: 776765184.1470242
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 265697730737.92114, tolerance: 824229861.8781899
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 247667905729.46628, tolerance: 799824502.1823168
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 223186815189.96906, tolerance: 801221726.127889
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 254218729984.4011, tolerance: 787313915.3852975
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 293665062272.3957, tolerance: 1012502428.4201145
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234893173859.58453, tolerance: 782105676.6192464
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 229914735642.9809, tolerance: 820431475.615667
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 228681496033.36673, tolerance: 833148680.3182864
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 226256776176.86786, tolerance: 816407969.5893532
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 214209720773.43164, tolerance: 797630643.9401869
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 301753080801.4115, tolerance: 987285992.466396
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 245661475575.5486, tolerance: 766928322.957384
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 235381644851.0009, tolerance: 786042640.3846164
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234435736242.15152, tolerance: 761069470.0753977
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 236287221806.7498, tolerance: 818454631.4670409
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 209691156001.3329, tolerance: 816571991.219279
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 299025043145.2679, tolerance: 944700189.6512867
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 215088782276.941, tolerance: 712927538.1076875
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233585428329.3268, tolerance: 760060365.4533167
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234572788257.7926, tolerance: 779526097.9794018
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233380286070.37683, tolerance: 770456400.8449037
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233505690629.82056, tolerance: 755454222.0865339
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 327947035009.27563, tolerance: 959824933.2558177
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 262890387010.32773, tolerance: 785308039.2332326
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233424308354.03662, tolerance: 792541313.591698
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 262159762295.78363, tolerance: 767042725.9184704
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 237954613666.0573, tolerance: 734007985.7569189
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 264964488620.9024, tolerance: 759821718.4402785
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 306472227106.1919, tolerance: 972127326.3268366
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 236891420100.5926, tolerance: 800906589.2550901
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 240590872125.45007, tolerance: 784808489.924945
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 232176747875.34634, tolerance: 745034438.3387207
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 244557985029.33743, tolerance: 802355146.0212576
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234998220311.06863, tolerance: 754183683.5088562
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 314163150599.7152, tolerance: 964288632.9803436
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 243623511823.86356, tolerance: 769377038.1049548
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 260403980018.54474, tolerance: 771699973.3454866
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234113473937.06198, tolerance: 744418482.8410807
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 238118399268.417, tolerance: 776558572.9150398
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 222397885853.6985, tolerance: 793696376.4903882
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 322076732533.82654, tolerance: 977080098.7355908
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 262145137215.53903, tolerance: 796900600.5990509
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 239109084883.2182, tolerance: 730564926.2327546
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 234327168648.74878, tolerance: 740045593.6461347
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 274566017165.55933, tolerance: 826992401.8784834
#   positive)
# C:\Users\awong\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 233690148277.2365, tolerance: 812054808.6843216
#   positive)
#    random_state  val_score  train_score  test_score
# 0          15.0       0.77         0.93        0.88
# 1          32.0       0.83         0.93        0.91
# 2          70.0       0.71         0.93        0.90
# 3           4.0       0.92         0.94        0.15
# 4          49.0       0.89         0.94        0.86
# 5          45.0       0.82         0.93        0.87
# 6          96.0       0.88         0.93        0.91
# 7          59.0       0.89         0.93        0.89
# 8           3.0       0.79         0.93        0.88
# 9          21.0       0.83         0.93        0.89

# %%
el_mysteps = [
    ('sc', StandardScaler()),
    ('lr', ElasticNet()) # estimator         
    ]

# %%
el_model = lr_model(df, 'saleprice', el_mysteps)

# %%
el_model.test_models(10)
# Out:
#    random_state  val_score  train_score  test_score
# 0          26.0       0.76         0.88        0.90
# 1          41.0       0.90         0.91        0.54
# 2          65.0       0.85         0.88        0.89
# 3          72.0       0.81         0.89        0.86
# 4          81.0       0.86         0.89        0.87
# 5          51.0       0.87         0.89        0.86
# 6          68.0       0.80         0.89        0.86
# 7           9.0       0.85         0.88        0.89
# 8          23.0       0.77         0.88        0.89
# 9          91.0       0.85         0.88        0.89
